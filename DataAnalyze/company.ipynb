# %%
import pandas as pd
import numpy as np 
data = pd.read_csv('company.csv')
data.head()
# Out:
#    cid company_name company_address company_level  \
# 0   84         野马智库              郑州           猪七戒
# 1   85       简至品牌设计              郑州           猪三戒
# 2   86       简渡品牌策划              郑州           猪五戒
# 3   87       三石品牌定制              郑州           猪六戒
# 4   88         蜂匠传媒             平顶山           猪四戒
#
#                                         company_icon  \
# 0  http://avatar.zbjimg.com/014/12/16/200x200_ava...
# 1  http://avatar.zbjimg.com/019/11/45/200x200_ava...
# 2  http://avatar.zbjimg.com/019/48/84/200x200_ava...
# 3  http://avatar.zbjimg.com/018/08/60/200x200_ava...
# 4  http://avatar.zbjimg.com/020/68/34/200x200_ava...
#
#                     company_link company_type  company_deposit  \
# 0  http://shop.zbj.com/14121668/           企业             6000
# 1  http://shop.zbj.com/19114520/           企业             1000
# 2  http://shop.zbj.com/19488457/           企业             5000
# 3  http://shop.zbj.com/18086003/           个人             5000
# ...

# %%
comment_data = pd.read_csv('comments.csv')
comment_data.head()
# Out:
#    comment_id                         user_name  \
# 0           1  **9291rai8le
# 1           2         **三千里
# 2           3         **侠87
# 3           4  **9429_lr7os8
# 4           5  **0542dm42jn
#
#                                            user_case     price  company_id  \
# 0  https://task.zbj.com/main/textimg.html?tid=100...      495元    10068282
# 1  https://task.zbj.com/main/textimg.html?tid=905...      800元    10068282
# 2  https://task.zbj.com/main/textimg.html?tid=998...  3300.66元    10068282
# 3  https://task.zbj.com/main/textimg.html?tid=100...     1300元    10068282
# 4  https://task.zbj.com/main/textimg.html?tid=100...      300元    10068282
#
#   comment_time                       impression    content
# 0   2017-02-16                             服务周到  挺好的 ！！！！！
# 1   2017-02-16  性价比高,沟通流畅,敬业,速度快,服务周到,质量很好,细致耐心  挺好的 ！！！！！
# 2   2017-02-16          性价比高,沟通流畅,态度好,服务周到,细致耐心  挺好的 ！！！！！
# 3   2017-02-16                    设计风格统一,提供优质案例  挺好的 ！！！！！
# ...
